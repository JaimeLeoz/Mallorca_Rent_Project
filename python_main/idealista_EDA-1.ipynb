# %%
import pandas as pd
import numpy as np

# %%
idealista = pd.read_excel(r'./Idealista/Mallorca_municipios_precio_sqm.xlsx',sheet_name ='final')
idealista.head()
# Out:
#    codigo_postal          municipio        mes  precio_m2  variacion_mensual  \
# 0            NaN  Palma de Mallorca 2022-08-01       12.5              0.033
# 1            NaN  Palma de Mallorca 2022-07-01       12.1              0.009
# 2            NaN  Palma de Mallorca 2022-06-01       11.9              0.009
# 3            NaN  Palma de Mallorca 2022-05-01       11.8              0.013
# 4            NaN  Palma de Mallorca 2022-04-01       11.7              0.008
#
#    variacion_anual
# 0            0.130
# 1            0.098
# 2            0.089
# 3            0.083
# 4            0.069

# %%
idealista.shape
# Out:
# (1259, 6)

# %%
idealista.drop_duplicates(inplace=True)

# %%
idealista.shape
# Out:
# (1259, 6)

# %%
idealista.municipio.value_counts()
# Out:
# Palma de Mallorca          80
# Eivissa                    80
# Santa Eulalia del Río      80
# Sant Josep de Sa Talaia    80
# Llucmajor                  80
# Baleares general           80
# Calvia                     80
# Sant Antoni de Portmany    77
# Andratx                    75
# Inca                       73
# Ciutadella de Menorca      67
# Manacor                    58
# Alcudia                    54
# Santa Margalida            45
# mao                        37
# Santanyi                   29
# Puerto Pollensa            22
# Campos                     21
# Sant Joan de Labritja      21
# Pollensa                   20
# Muro                       15
# Porto Colom                14
# Soller                     13
# Colonia de Sant Jordi      12
# Felanitx                   12
# Pobla                      11
# Esporles                   10
# Sa Rapita                   8
# Santa Maria del Cami        3
# Ses salines                 2
# Name: municipio, dtype: int64

# %% [markdown]
# ## Municipios clean

# %%
# LLORO DE ALEGRIA, ANDA QUE NO ERA JODIDO 
# lista de los municipios y como deberian quedar

municipios_clean=[]

for i in idealista.municipio:
    if i.find("Alar") >=0:
        municipios_clean.append("Alaro")
    elif i.find("Alc") >=0:
        municipios_clean.append("Alcudia")
    elif i.find("Algai") >=0:
        municipios_clean.append("Algaida")
    elif i.find("Andra") >=0:
        municipios_clean.append("Andratx")
    elif i.find("Aria") >=0:
        municipios_clean.append("Ariany")
    elif i.find("Art") >=0:
        municipios_clean.append("Arta")
    elif i.find("Artà") >=0:
        municipios_clean.append("Arta")    

    elif i.find("Baña") >=0:
        municipios_clean.append("Banyalbufar")
    elif i.find("Banya") >=0:
        municipios_clean.append("Banyalbufar")
    elif i.find("Búger") >=0:
        municipios_clean.append("Buger")
    elif i.find("Buger") >=0:
        municipios_clean.append("Buger")
    elif i.find("Buñ") >=0:
        municipios_clean.append("Bunyola")
    elif i.find("Bun") >=0:
        municipios_clean.append("Bunyola")
    elif i.find("Calv") >=0:
        municipios_clean.append("Calvia")
    elif i.find("Campa") >=0:
        municipios_clean.append("Campanet")
    elif i.find("Campo") >=0:
        municipios_clean.append("Campos")
        
    elif i.find("Colonia de") >=0:
        municipios_clean.append("Colonia de Sant Jordi")  
    elif i.find("Costi") >=0:
        municipios_clean.append("Costitx")
    elif i.find("Dey") >=0:
        municipios_clean.append("Deia")
    elif i.find("Espor") >=0:
        municipios_clean.append("Esporles")
    elif i.find("Estell") >=0:
        municipios_clean.append("Estellencs")
    elif i.find("es Cast") >=0:
        municipios_clean.append("Es Castell")


    elif i.find("Felani") >=0:
        municipios_clean.append("Felanitx")
    elif i.find("Fornal") >=0:
        municipios_clean.append("Fornalutx")
    elif i.find("Sa Pob") >=0:
        municipios_clean.append("Sa Pobla")
    elif i.find("Pobl") >=0:
        municipios_clean.append("Sa Pobla")
    elif i.find("Las Sal") >=0:
        municipios_clean.append("Ses Salines")
    elif i.find("Ses Sal") >=0:
        municipios_clean.append("Ses Salines")
    

    elif i.find("Salin") >=0:
        municipios_clean.append("Ses Salines")
    elif i.find("Llor") >=0:
        municipios_clean.append("Lloret de Vistalegre")
    elif i.find("Llos") >=0:
        municipios_clean.append("Lloseta")
    elif i.find("Llub") >=0:
        municipios_clean.append("Llubi")
    elif i.find("Lluc") >=0:
        municipios_clean.append("Llucmajor")
    elif i.find("Llub") >=0:
        municipios_clean.append("Llubi")
    elif i.find("Manc") >=0:
        municipios_clean.append("Mancor de la Vall")

    elif i.find("Maó") >=0:
        municipios_clean.append("Mao")
    elif i.find("Mah") >=0:
        municipios_clean.append("Mao")
    elif i.find("mao") >=0:
        municipios_clean.append("Mao")       


    elif i.find("Marra") >=0:
        municipios_clean.append("Marratxi")
    elif i.find("Montu") >=0:
        municipios_clean.append("Montuiri")
    elif i.find("Palma") >=0:
        municipios_clean.append("Palma de Mallorca")
    elif i.find("Polle") >=0:
        municipios_clean.append("Pollensa")
    elif i.find("Porr") >=0:
        municipios_clean.append("Porreres")
    elif i.find("Porto Col") >=0:
        municipios_clean.append("Porto Colom")
    elif i.find("Puig") >=0:
        municipios_clean.append("Puigpunyent")
    elif i.find("San Ju") >=0:
        municipios_clean.append("Sant Joan")
    elif i.find("Juan") >=0:
        municipios_clean.append("Sant Joan")
    elif i.find("Sa Rapi") >=0:
        municipios_clean.append("Sa Rapita")
    elif i.find("San Llor") >=0:
        municipios_clean.append("Sant Lloren des Cardassar")    
    elif i.find("Sanc") >=0:
        municipios_clean.append("Sencelles")
    elif i.find("Santa eug") >=0:
        municipios_clean.append("Santa Eugenia")
    elif i.find("Santa Eulalia del ") >=0:
        municipios_clean.append("Santa Eularia des Riu") 
    elif i.find("Santa Marg") >=0:
        municipios_clean.append("Santa Margalida")
    elif i.find("Santa Mar") >=0:
        municipios_clean.append("Santa Maria del Cami")
    elif i.find("San Josep") >=0:
        municipios_clean.append("Sant Josep de Sa Talaia")   
    elif i.find("Ses salin") >=0:
        municipios_clean.append("Ses Salines")

         
    elif i.find("Santañ") >=0:
        municipios_clean.append("Santanyi")
    elif i.find("Santan") >=0:
        municipios_clean.append("Santanyi")
    elif i.find("Síne") >=0:
        municipios_clean.append("Sineu")
    elif i.find("Sóll") >=0:
        municipios_clean.append("Soller")
    elif i.find("Síne") >=0:
        municipios_clean.append("Sineu")
    else:
        municipios_clean.append(i)

idealista.municipio = municipios_clean

# %%
idealista.municipio.value_counts()
# Out:
# Palma de Mallorca          80
# Eivissa                    80
# Santa Eularia des Riu      80
# Sant Josep de Sa Talaia    80
# Llucmajor                  80
# Baleares general           80
# Calvia                     80
# Sant Antoni de Portmany    77
# Andratx                    75
# Inca                       73
# Ciutadella de Menorca      67
# Manacor                    58
# Alcudia                    54
# Santa Margalida            45
# Pollensa                   42
# Mao                        37
# Santanyi                   29
# Sant Joan de Labritja      21
# Campos                     21
# Muro                       15
# Porto Colom                14
# Soller                     13
# Felanitx                   12
# Colonia de Sant Jordi      12
# Sa Pobla                   11
# Esporles                   10
# Sa Rapita                   8
# Santa Maria del Cami        3
# Ses Salines                 2
# Name: municipio, dtype: int64

# %% [markdown]
# ## Postal codes add up

# %%
# POSTAL CODES ITERATIONS!
# lista de los municipios y como deberian quedar

postal_codes = []

for i in idealista["municipio"]:

    if i.find("Alaior") ==0:
        postal_codes.append("7730")

    if i.find("Alaro") ==0:
        postal_codes.append("7340")
    elif i.find("Alcudia") ==0:
        postal_codes.append("7400")
    elif i.find("Algaida") ==0:
        postal_codes.append("7210")
    elif i.find("Andratx") ==0:
        postal_codes.append("7150")
    elif i.find("Ariany") ==0:
        postal_codes.append("7529")
    elif i.find("Arta") ==0:
        postal_codes.append("7570")
 

    elif i.find("Banyalbufar") ==0:
        postal_codes.append("7191")
    elif i.find("Buger") ==0:
        postal_codes.append("7311")
    elif i.find("Binissalem") ==0:
        postal_codes.append("7350")
    elif i.find("Bunyola") ==0:
        postal_codes.append("7110")
 
    elif i.find("Calvia") ==0:
        postal_codes.append("7184")
    elif i.find("Campanet") ==0:
        postal_codes.append("7310")
    elif i.find("Campos") ==0:
        postal_codes.append("7630")
    elif i.find("Capdepera") ==0:
        postal_codes.append("7580")
    elif i.find("Es Castell") ==0:
        postal_codes.append("7409")
    elif i.find("Ciutadella de Menorca") ==0:
        postal_codes.append("7760")
    elif i.find("Consell") ==0:
        postal_codes.append("7330")
    elif i.find("Costitx") ==0:
        postal_codes.append("7144")
    elif i.find("Colonia de Sant Jordi") ==0:
        postal_codes.append("7638")  


    elif i.find("Deia") ==0:
        postal_codes.append("7179")

    elif i.find("Eivissa") ==0:
        postal_codes.append("7800")
    elif i.find("Escorca") ==0:
        postal_codes.append("7315")
    elif i.find("Estellencs") ==0:
        postal_codes.append("7192")
    elif i.find("Esporles") ==0:
        postal_codes.append("7190")


    elif i.find("Felanitx") ==0:
        postal_codes.append("7200")
    elif i.find("Ferreries") ==0:
        postal_codes.append("7750")
    elif i.find("Formentera") ==0:
        postal_codes.append("7470")  
    elif i.find("Fornalutx") ==0:
        postal_codes.append("7109")
    elif i.find("Inca") ==0:
        postal_codes.append("7300")


    elif i.find("LLoseta") ==0:
        postal_codes.append("7360")
    elif i.find("Llubi") ==0:
        postal_codes.append("7430")
    elif i.find("Lloret de Vistal") ==0:
        postal_codes.append("7518")

    elif i.find("Llucmajor") ==0:
        postal_codes.append("7620")

    elif i.find("Manacor") ==0:
        postal_codes.append("7500")
    elif i.find("Mancor de") ==0:
        postal_codes.append("7312")
    elif i.find("Mao") ==0:
        postal_codes.append("7700")     
    elif i.find("Maria de la Salut") ==0:
        postal_codes.append("7519")
    elif i.find("Marratxi") ==0:
        postal_codes.append("7141")
    elif i.find("Es Mercadal") ==0:
        postal_codes.append("7740")
    elif i.find("Montuiri") ==0:
        postal_codes.append("7230")
    elif i.find("Muro") ==0:
        postal_codes.append("7440")     

    elif i.find("Palma de Mallorca") ==0:
        postal_codes.append("7001")
    elif i.find("Petra") ==0:
        postal_codes.append("7520")
    elif i.find("Sa Pobla") ==0:
        postal_codes.append("7420")
    elif i.find("Pollensa") ==0:
        postal_codes.append("7460")
    elif i.find("Porto Colom") ==0:
        postal_codes.append("7670")
    

    elif i.find("Porreres") ==0:
        postal_codes.append("7260")
    elif i.find("Puigpunyent") ==0:
        postal_codes.append("7194")
    elif i.find("Ses Salines") ==0:
        postal_codes.append("7748")
    elif i.find("Sant Antoni de Portmany") ==0:
        postal_codes.append("7820")
    elif i.find("San Joan") ==0:
        postal_codes.append("7240")
    elif i.find("Sant Lloren des Cardassar") ==0:
        postal_codes.append("7530")
    elif i.find("Sant Lluís") ==0:
        postal_codes.append("7710")
    elif i.find("Sant Joan de Labritja") ==0:
        postal_codes.append("7810")
    elif i.find("Sant Josep de Sa Talaia") ==0:
        postal_codes.append("7830")     

    elif i.find("Santa Eugènia") ==0:
        postal_codes.append("7142")

    elif i.find("Santa Eularia des Riu") ==0:
        postal_codes.append("7840")
    elif i.find("Santa Eulalia del Río") ==0:
        postal_codes.append("7840")
    elif i.find("Santa Margalida") ==0:
        postal_codes.append("7450")
    elif i.find("Santa Maria del Cami") ==0:
        postal_codes.append("7320")
    elif i.find("Santanyi") ==0:
        postal_codes.append("7650")
    elif i.find("Sa Rapita") ==0:
        postal_codes.append("7639")
    elif i.find("Selva") ==0:
        postal_codes.append("7313")
    elif i.find("Sencelles") ==0:
        postal_codes.append("7140")
    elif i.find("Sineu") ==0:
        postal_codes.append("7510")
    elif i.find("Soller") ==0:
        postal_codes.append("7100")
    elif i.find("Son Servera") ==0:
        postal_codes.append("7550")
    
    elif i.find("Valldemossa") ==0:
        postal_codes.append("7170")
    elif i.find("Vilafranc de") ==0:
        postal_codes.append("7250")       
    elif i.find("Baleares general") ==0:
        postal_codes.append("7000")

    else:
        postal_codes.append(i)

idealista["postal_codes_idealista"] = postal_codes

# %%
from itertools import groupby


idealista[['postal_codes_idealista', 'municipio']].tail(50)
# Out:
#      postal_codes_idealista         municipio
# 1209                   7000  Baleares general
# 1210                   7000  Baleares general
# 1211                   7000  Baleares general
# 1212                   7000  Baleares general
# 1213                   7000  Baleares general
# 1214                   7000  Baleares general
# 1215                   7000  Baleares general
# 1216                   7000  Baleares general
# 1217                   7000  Baleares general
# 1218                   7000  Baleares general
# 1219                   7000  Baleares general
# 1220                   7000  Baleares general
# 1221                   7000  Baleares general
# 1222                   7000  Baleares general
# 1223                   7000  Baleares general
# 1224                   7000  Baleares general
# 1225                   7000  Baleares general
# 1226                   7000  Baleares general
# 1227                   7000  Baleares general
# 1228                   7000  Baleares general
# 1229                   7000  Baleares general
# 1230                   7000  Baleares general
# 1231                   7000  Baleares general
# 1232                   7000  Baleares general
# 1233                   7000  Baleares general
# 1234                   7000  Baleares general
# 1235                   7000  Baleares general
# 1236                   7000  Baleares general
# 1237                   7000  Baleares general
# 1238                   7000  Baleares general
# 1239                   7000  Baleares general
# 1240                   7000  Baleares general
# 1241                   7000  Baleares general
# 1242                   7000  Baleares general
# 1243                   7000  Baleares general
# 1244                   7000  Baleares general
# 1245                   7000  Baleares general
# 1246                   7000  Baleares general
# 1247                   7000  Baleares general
# 1248                   7000  Baleares general
# 1249                   7000  Baleares general
# 1250                   7000  Baleares general
# 1251                   7000  Baleares general
# 1252                   7000  Baleares general
# 1253                   7000  Baleares general
# 1254                   7000  Baleares general
# 1255                   7000  Baleares general
# 1256                   7000  Baleares general
# 1257                   7000  Baleares general
# 1258                   7000  Baleares general

# %%
idealista.postal_codes_idealista.value_counts()
# Out:
# 7001    80
# 7800    80
# 7840    80
# 7830    80
# 7620    80
# 7000    80
# 7184    80
# 7820    77
# 7150    75
# 7300    73
# 7760    67
# 7500    58
# 7400    54
# 7450    45
# 7460    42
# 7700    37
# 7650    29
# 7810    21
# 7630    21
# 7440    15
# 7670    14
# 7100    13
# 7200    12
# 7638    12
# 7420    11
# 7190    10
# 7639     8
# 7320     3
# 7748     2
# Name: postal_codes_idealista, dtype: int64

# %%
idealista.head()
# Out:
#    codigo_postal          municipio        mes  precio_m2  variacion_mensual  \
# 0            NaN  Palma de Mallorca 2022-08-01       12.5              0.033
# 1            NaN  Palma de Mallorca 2022-07-01       12.1              0.009
# 2            NaN  Palma de Mallorca 2022-06-01       11.9              0.009
# 3            NaN  Palma de Mallorca 2022-05-01       11.8              0.013
# 4            NaN  Palma de Mallorca 2022-04-01       11.7              0.008
#
#    variacion_anual postal_codes_idealista
# 0            0.130                   7001
# 1            0.098                   7001
# 2            0.089                   7001
# 3            0.083                   7001
# 4            0.069                   7001

# %%
idealista.to_excel(r'./Idealista/idealista_final.xlsx', index=False)

# %%
idealista = idealista.drop('codigo_postal', axis=1)

# %%
idealista.head()
# Out:
#            municipio        mes  precio_m2  variacion_mensual  \
# 0  Palma de Mallorca 2022-08-01       12.5              0.033
# 1  Palma de Mallorca 2022-07-01       12.1              0.009
# 2  Palma de Mallorca 2022-06-01       11.9              0.009
# 3  Palma de Mallorca 2022-05-01       11.8              0.013
# 4  Palma de Mallorca 2022-04-01       11.7              0.008
#
#    variacion_anual postal_codes_idealista
# 0            0.130                   7001
# 1            0.098                   7001
# 2            0.089                   7001
# 3            0.083                   7001
# 4            0.069                   7001

# %%
idealista['year_month'] = pd.to_datetime(idealista['mes']).dt.strftime('%Y-%m')

# %%
idealista.head()
# Out:
#            municipio        mes  precio_m2  variacion_mensual  \
# 0  Palma de Mallorca 2022-08-01       12.5              0.033
# 1  Palma de Mallorca 2022-07-01       12.1              0.009
# 2  Palma de Mallorca 2022-06-01       11.9              0.009
# 3  Palma de Mallorca 2022-05-01       11.8              0.013
# 4  Palma de Mallorca 2022-04-01       11.7              0.008
#
#    variacion_anual postal_codes_idealista year_month
# 0            0.130                   7001    2022-08
# 1            0.098                   7001    2022-07
# 2            0.089                   7001    2022-06
# 3            0.083                   7001    2022-05
# 4            0.069                   7001    2022-04

# %% [markdown]
# ## EDA

# %%
idealista.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   municipio               1259 non-null   object
#  1   mes                     1259 non-null   datetime64[ns]
#  2   precio_m2               1259 non-null   float64
#  3   variacion_mensual       1211 non-null   float64
#  4   variacion_anual         1026 non-null   float64
#  5   postal_codes_idealista  1259 non-null   object
#  6   year_month              1259 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 78.7+ KB

# %%
pd.to_datetime(idealista['year_month'])
# Out:
# 0      2022-08-01
# 1      2022-07-01
# 2      2022-06-01
# 3      2022-05-01
# 4      2022-04-01
#           ...
# 1254   2016-05-01
# 1255   2016-04-01
# 1256   2016-03-01
# 1257   2016-02-01
# 1258   2016-01-01
# Name: year_month, Length: 1259, dtype: datetime64[ns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
idealista.precio_m2.hist()
# Out:
# <AxesSubplot:>

# %%
import pylab as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import pylab as plt                                # plotting library
import seaborn as sns

# %%
sns.distplot(idealista['precio_m2'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='precio_m2', ylabel='Density'>

# %% [markdown]
# ## To SQL

# %%
import sys
import csv
import glob
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
str_conn=f'mysql+pymysql://root:password@localhost:3306'

cursor=create_engine(str_conn)

#cursor.execute('drop database if exists final_airbnb_project;')

#cursor.execute('create database final_airbnb_project;')

# %%
str_conn=f'mysql+pymysql://root:password@localhost:3306/the_final_airbnb_project'

cursor_db=create_engine(str_conn)

# %%
#idealista.to_sql(name='idealista_final', con=cursor_db, if_exists='replace', index=False)
# Out:
# 1259

# %%
#idealista.to_excel(r'./SQL/idealista_final.xlsx', index=False)

# %%
#evolution_graph = pd.read_sql('f_evolution_graph_table',str_conn)
#evolution_graph
# Out:
#     COUNT(last_scraped_month) last_scraped_month  avg(price_sqm_euros_month)  \
# 0                       98546            2017-05                   54.664182
# 1                      106821            2016-05                   52.158741
# 2                       83811            2017-08                   58.547313
# 3                      233544            2020-12                   68.404115
# 4                      474550            2021-01                   67.881659
# ..                        ...                ...                         ...
# 68                     338560            2021-04                   69.354228
# 69                     257040            2021-09                   80.539761
# 70                     167651            2020-04                   65.626051
# 71                     340193            2020-10                   67.048331
# 72                     135234            2019-08                   62.746356
#
#     avg(precio_m2)
# 0        11.728571
# 1         9.511111
# 2        11.985714
# 3         9.641667
# 4         9.248000
# ..             ...
# 68        9.326087
# 69       10.122222
# 70       11.336364
# 71        9.860870
# 72       11.566667
#
# [73 rows x 4 columns]

# %%
#evolution_graph.to_excel(r'./SQL/evolution_graph_idealista_airbnb.xlsx', index=False)

# %%
palma_evolution_graph = pd.read_sql('palma_evolution',str_conn)
palma_evolution_graph
# Out:
#     COUNT(last_scraped_month) last_scraped_month  avg(price_sqm_euros_month)  \
# 0                        2676            2017-05                   45.701808
# 1                        2758            2016-05                   43.726315
# 2                        1571            2017-08                   51.302905
# 3                        2057            2021-01                   52.708677
# 4                        1093            2020-12                   58.266059
# ..                        ...                ...                         ...
# 68                       1569            2021-04                   57.094481
# 69                       1591            2021-09                   65.018774
# 70                       1782            2020-04                   59.500329
# 71                       1592            2020-10                   53.409458
# 72                       1791            2019-08                   55.299376
#
#     avg(precio_m2) neighbourhood_cleansed          municipio
# 0             10.7      Palma de Mallorca  Palma de Mallorca
# 1              9.1      Palma de Mallorca  Palma de Mallorca
# 2             10.9      Palma de Mallorca  Palma de Mallorca
# 3             11.0      Palma de Mallorca  Palma de Mallorca
# 4             11.2      Palma de Mallorca  Palma de Mallorca
# ..             ...                    ...                ...
# 68            10.9      Palma de Mallorca  Palma de Mallorca
# 69            11.2      Palma de Mallorca  Palma de Mallorca
# 70            12.2      Palma de Mallorca  Palma de Mallorca
# 71            11.5      Palma de Mallorca  Palma de Mallorca
# 72            12.0      Palma de Mallorca  Palma de Mallorca
#
# [73 rows x 6 columns]

# %%
palma_evolution_graph.to_excel(r'./SQL/palma_evolution.xlsx', index=False)

# %%
alcudia_evolution_graph = pd.read_sql('alcudia_evolution',str_conn)
alcudia_evolution_graph.head()
# Out:
#    COUNT(last_scraped_month) last_scraped_month  avg(price_sqm_euros_month)  \
# 0                       1889            2021-01                   65.309528
# 1                       1031            2020-12                   65.144011
# 2                       1490            2021-12                   66.125670
# 3                       1466            2019-12                   58.304264
# 4                       1567            2022-01                   57.474560
#
#    avg(precio_m2) neighbourhood_cleansed municipio
# 0             9.9                Alcudia   Alcudia
# 1             9.8                Alcudia   Alcudia
# 2            10.1                Alcudia   Alcudia
# 3            10.6                Alcudia   Alcudia
# 4            10.2                Alcudia   Alcudia

# %%
alcudia_evolution_graph.to_excel(r'./SQL/alcudia_evolution.xlsx', index=False)

# %%
pollensa_evolution_graph = pd.read_sql('pollensa_evolution',str_conn)
pollensa_evolution_graph.head()
# Out:
#    COUNT(last_scraped_month) last_scraped_month  avg(price_sqm_euros_month)  \
# 0                       2588            2020-12                   70.647308
# 1                       4822            2021-01                   70.646307
# 2                       4024            2021-12                   73.637428
# 3                       4404            2022-01                   64.419159
# 4                       4144            2021-11                   73.896647
#
#    avg(precio_m2) neighbourhood_cleansed municipio
# 0            9.80               Pollensa  Pollensa
# 1            9.70               Pollensa  Pollensa
# 2           10.80               Pollensa  Pollensa
# 3           10.55               Pollensa  Pollensa
# 4           10.85               Pollensa  Pollensa

# %%
pollensa_evolution_graph.to_excel(r'./SQL/pollensa_evolution.xlsx', index=False)
